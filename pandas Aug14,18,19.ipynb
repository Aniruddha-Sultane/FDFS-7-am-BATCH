# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
df=pd.read_csv(r'C:\Users\Aniruddha Sultane\Downloads\data.csv')

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
len(df)
# Out:
# 195

# %%
id(df)
# Out:
# 2160861303808

# %%
df.shape                    #shape gives you how many no. of rows and column
# Out:
# (195, 5)

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 5

# %%
len(df.index)
# Out:
# 195

# %%
df.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df.head
# Out:
# <bound method NDFrame.head of               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]>

# %%
df.head()                      #this is used for print first five rows
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.head(2)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0        Aruba         ABW     10.244           78.9  High income
# 1  Afghanistan         AFG     35.253            5.9   Low income

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [CountryName, CountryCode, BirthRate, InternetUsers, IncomeGroup]
# Index: []

# %%
df.head(200)
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
df.tail()       #this is used for getting the last 5 rows of the dataframe we can also specify the number of rows we want
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.tail(20)
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 175                         Tunisia         TUN     19.800          43.80
# 176                          Turkey         TUR     16.836          46.25
# 177                        Tanzania         TZA     39.518           4.40
# 178                          Uganda         UGA     43.474          16.20
# 179                         Ukraine         UKR     11.100          41.00
# 180                         Uruguay         URY     14.374          57.69
# 181                   United States         USA     12.500          84.20
# 182                      Uzbekistan         UZB     22.500          38.20
# 183  St. Vincent and the Grenadines         VCT     16.306          52.00
# 184                   Venezuela, RB         VEN     19.842          54.90
# 185           Virgin Islands (U.S.)         VIR     10.700          45.30
# 186                         Vietnam         VNM     15.537          43.90
# 187                         Vanuatu         VUT     26.739          11.30
# 188              West Bank and Gaza         PSE     30.394          46.60
# 189                           Samoa         WSM     26.172          15.30
# 190                     Yemen, Rep.         YEM     32.947          20.00
# 191                    South Africa         ZAF     20.850          46.50
# 192                Congo, Dem. Rep.         COD     42.394           2.20
# 193                          Zambia         ZMB     40.471          15.40
# 194                        Zimbabwe         ZWE     35.715          18.50
#
#              IncomeGroup
# 175  Upper middle income
# 176  Upper middle income
# 177           Low income
# 178           Low income
# 179  Lower middle income
# 180          High income
# 181          High income
# 182  Lower middle income
# 183  Upper middle income
# 184          High income
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.dtypes
# Out:
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# dtype: object

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
df_cat=df[['CountryName','CountryCode','IncomeGroup']]           #cat means categorial data
df_cat                                                            #categorial data means objective data
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
df_num=df[['BirthRate','InternetUsers']]                   #num means numerical data
df_num                                                     #numerical data means numeric data
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
print(df.shape)
print(df_cat.shape)
print(df_num.shape)
# Out:
# (195, 5)
# (195, 3)
# (195, 2)

# %%
df[:5]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df[5:]
# Out:
#              CountryName CountryCode  BirthRate  InternetUsers  \
# 5              Argentina         ARG     17.716        59.9000
# 6                Armenia         ARM     13.308        41.9000
# 7    Antigua and Barbuda         ATG     16.447        63.4000
# 8              Australia         AUS     13.200        83.0000
# 9                Austria         AUT      9.400        80.6188
# ..                   ...         ...        ...            ...
# 190          Yemen, Rep.         YEM     32.947        20.0000
# 191         South Africa         ZAF     20.850        46.5000
# 192     Congo, Dem. Rep.         COD     42.394         2.2000
# 193               Zambia         ZMB     40.471        15.4000
# 194             Zimbabwe         ZWE     35.715        18.5000
#
#              IncomeGroup
# 5            High income
# 6    Lower middle income
# 7            High income
# 8            High income
# 9            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [190 rows x 5 columns]

# %%
df[1:200:20]
# Out:
#          CountryName CountryCode  BirthRate  InternetUsers  \
# 1        Afghanistan         AFG     35.253         5.9000
# 21            Belize         BLZ     23.092        33.6000
# 41              Cuba         CUB     10.400        27.9300
# 61    United Kingdom         GBR     12.200        89.8441
# 81           Ireland         IRL     15.000        78.2477
# 101        St. Lucia         LCA     15.430        46.2000
# 121       Mauritania         MRT     33.801         6.2000
# 141      Puerto Rico         PRI     10.800        73.9000
# 161  Slovak Republic         SVK     10.100        77.8826
# 181    United States         USA     12.500        84.2000
#
#              IncomeGroup
# 1             Low income
# 21   Upper middle income
# 41   Upper middle income
# 61           High income
# 81           High income
# 101  Upper middle income
# 121  Lower middle income
# 141          High income
# 161          High income
# 181          High income

# %%
df[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# 4            High income
# 3    Upper middle income
# 2    Upper middle income
# 1             Low income
# 0            High income
#
# [195 rows x 5 columns]

# %%
df[::-5]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 194                  Zimbabwe         ZWE     35.715        18.5000
# 189                     Samoa         WSM     26.172        15.3000
# 184             Venezuela, RB         VEN     19.842        54.9000
# 179                   Ukraine         UKR     11.100        41.0000
# 174       Trinidad and Tobago         TTO     14.590        63.8000
# 169                  Thailand         THA     11.041        28.9400
# 164                 Swaziland         SWZ     30.093        24.7000
# 159     Sao Tome and Principe         STP     34.537        23.0000
# 154              Sierra Leone         SLE     36.729         1.7000
# 149              Saudi Arabia         SAU     20.576        60.5000
# 144          French Polynesia         PYF     16.393        56.8000
# 139          Papua New Guinea         PNG     28.899         6.5000
# 134                      Oman         OMN     20.419        66.4500
# 129                 Nicaragua         NIC     20.788        15.5000
# 124                  Malaysia         MYS     16.805        66.9700
# 119                  Mongolia         MNG     24.275        20.0000
# 114            Macedonia, FYR         MKD     11.222        65.2400
# 109                   Morocco         MAR     21.023        56.0000
# 104                   Lesotho         LSO     28.738         5.0000
# 99                    Liberia         LBR     35.521         3.2000
# 94                   Kiribati         KIR     29.044        11.5000
# 89                      Japan         JPN      8.200        89.7100
# 84                    Iceland         ISL     13.400        96.5468
# 79                  Indonesia         IDN     20.297        14.9400
# 74       Hong Kong SAR, China         HKG      7.900        74.2000
# 69                    Grenada         GRD     19.334        35.0000
# 64                     Guinea         GIN     37.337         1.6000
# 59      Micronesia, Fed. Sts.         FSM     23.511        27.8000
# 54                    Estonia         EST     10.300        79.4000
# 49                    Algeria         DZA     24.738        16.5000
# 44             Czech Republic         CZE     10.200        74.1104
# 39                 Cabo Verde         CPV     21.625        37.5000
# 34              Cote d'Ivoire         CIV     37.320         8.4000
# 29   Central African Republic         CAF     34.076         3.5000
# 24                     Brazil         BRA     14.931        51.0400
# 19     Bosnia and Herzegovina         BIH      9.062        57.7900
# 14               Burkina Faso         BFA     40.551         9.1000
# 9                     Austria         AUT      9.400        80.6188
# 4        United Arab Emirates         ARE     11.044        88.0000
#
#              IncomeGroup
# 194           Low income
# 189  Lower middle income
# 184          High income
# 179  Lower middle income
# 174          High income
# 169  Upper middle income
# 164  Lower middle income
# 159  Lower middle income
# 154           Low income
# 149          High income
# 144          High income
# 139  Lower middle income
# 134          High income
# 129  Lower middle income
# 124  Upper middle income
# 119  Upper middle income
# 114  Upper middle income
# 109  Lower middle income
# 104  Lower middle income
# 99            Low income
# 94   Lower middle income
# 89           High income
# 84           High income
# 79   Lower middle income
# 74           High income
# 69   Upper middle income
# 64            Low income
# 59   Lower middle income
# 54           High income
# 49   Upper middle income
# 44           High income
# 39   Lower middle income
# 34   Lower middle income
# 29            Low income
# 24   Upper middle income
# 19   Upper middle income
# 14            Low income
# 9            High income
# 4            High income

# %%
df.describe()                #gives you statistical summary of the data
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df.describe().transpose()
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468

# %%
df_num.describe()  #gives you statistical summary of the data
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_cat.describe()
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %%
df.head(1)                    #head is used fod display the row
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
df.columns=['a','b','c','d','e']       #used  for rename a column
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df.head(1)
# Out:
#        a    b       c     d            e
# 0  Aruba  ABW  10.244  78.9  High income

# %%
df.columns=['CountryName','CountryCode',	'BirthRate',	'InternetUsers',	'IncomeGroup']

# %%
df.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
df.head(3)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0        Aruba         ABW     10.244           78.9          High income
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income

# %%
df.columns=['a','b','c','d','e']

# %%
df.head(3)
# Out:
#              a    b       c     d                    e
# 0        Aruba  ABW  10.244  78.9          High income
# 1  Afghanistan  AFG  35.253   5.9           Low income
# 2       Angola  AGO  45.985  19.1  Upper middle income

# %%
df.columns=['CountryName','CountryCode',	'BirthRate',	'InternetUsers',	'IncomeGroup']
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.BirthRate * df.InternetUsers
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
df.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
df['myCalc']=df.BirthRate * df.InternetUsers

# %%
df['myCalc']
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Name: myCalc, Length: 195, dtype: float64

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    myCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
df=df.drop('myCalc',axis=1)

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
df['InternetUsers'] <2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
df[df['InternetUsers'] <2]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
len(df[df['InternetUsers'] < 2])
# Out:
# 9

# %%
filter_1=df[df['InternetUsers'] < 2]
filter_1
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
filter_2=df[df['BirthRate']>40]
filter_2
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# 128  Lower middle income
# 156           Low income
# 167           Low income
# 178           Low income
# 192           Low income
# 193  Lower middle income

# %%
df[(df.BirthRate>40) & (df.InternetUsers<2)]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
df.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
df[df.IncomeGroup=='High income'].head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                 Aruba         ABW     10.244           78.9  High income
# 4  United Arab Emirates         ARE     11.044           88.0  High income
# 5             Argentina         ARG     17.716           59.9  High income
# 7   Antigua and Barbuda         ATG     16.447           63.4  High income
# 8             Australia         AUS     13.200           83.0  High income

# %%
df.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
df.IncomeGroup.nunique()
# Out:
# 4

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\aniruddha sultane\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\aniruddha sultane\anaconda3\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\aniruddha sultane\anaconda3\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\aniruddha sultane\anaconda3\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aniruddha sultane\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aniruddha sultane\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aniruddha sultane\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aniruddha sultane\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\aniruddha sultane\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\aniruddha sultane\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aniruddha sultane\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aniruddha sultane\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aniruddha sultane\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aniruddha sultane\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\aniruddha sultane\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize']=6,2
import warnings
warnings.filterwarnings('ignore')

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
vis1=sns.distplot(df['InternetUsers'])

# %%
vis2 = sns.displot(df['InternetUsers'])
plt.show(vis2)

# %%
vis3 = sns.distplot(df['InternetUsers'], bins=15)
plt.show(vis3)

# %%
vis4 = sns.boxplot(data=df ,x='IncomeGroup', y='BirthRate')
plt.show(vis4)

# %%
vis5 = sns.lmplot(data = df, x='InternetUsers', y='BirthRate')
plt.show(vis5)

# %%
vis6 = sns.lmplot(data = df, x='InternetUsers', y='BirthRate',fit_reg=False)
plt.show(vis6)

# %%
vis7 = sns.lmplot(data = df, x='InternetUsers', y='BirthRate',fit_reg=True)
plt.show(vis7)

# %%
vis8 = sns.lmplot(data = df, x='InternetUsers', y='BirthRate',fit_reg=False,hue='IncomeGroup')
plt.show(vis8)

# %%
vis9 = sns.lmplot(data = df, x='InternetUsers', y='BirthRate',fit_reg=True,hue='IncomeGroup')
plt.show(vis9)

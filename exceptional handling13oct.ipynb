# %%
a=4
b=0


print(a/b)
print('hey')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 a=4
#       2 b=0
# ----> 5 print(a/b)
#       6 print('hey')
#
# ZeroDivisionError: division by zero

# %%
a=4
b=0


print('hey')
print(a/b)
# Out:
# hey
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 6
#       2 b=0
#       5 print('hey')
# ----> 6 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
a=5
b=0

try:
    print(a/b)
    
except Exception:
    print('hey')
# Out:
# hey

# %%
a=4
b=0

try: 
    print(b/a)
    
except Exception:
    print('heyyy')
# Out:
# 0.0

# %%
a=4
b=0

try: 
    print(b/a)
    
except Exception:
    print('heyyy')
    
print('hey babes')
# Out:
# 0.0
# hey babes

# %%
a=4
b=0

try: 
    print(a/b)
    
except Exception:
    print('heyyy')
    
print('hey babes')
# Out:
# heyyy
# hey babes

# %%
a=4
b=0

try: 
    print(a/b)
    
except Exception as e:
    print('heyyy')
    
print('hey babes')
# Out:
# heyyy
# hey babes

# %%
a=4
b=0

try: 
    print(b/a)
    
except Exception as e:
    print('heyyy')
    
print('hey babes')
# Out:
# 0.0
# hey babes

# %%
a=4
b=0

try: 
    print(a/b)
    
except Exception as e:
    print('error because',e)
    
print('hey babes')
# Out:
# error because division by zero
# hey babes

# %%
a=3
b=3

try:
    print('resource open')
    print(a/b)
    print('resource closed')
    
except Exception as e:
    print('error because',e)
# Out:
# resource open
# 1.0
# resource closed

# %%
a=3
b=0

try:
    print('resource open')
    print(b/a)
    print('resource closed')
    
except Exception as e:
    print('error because',e)
# Out:
# resource open
# 0.0
# resource closed

# %%
a=3
b=0

try:
    print('resource open')
    print(a/b)
    print('resource closed')
    
except Exception as e:
    print('error because',e)
# Out:
# resource open
# error because division by zero

# %%
a=3
b=0

try:
    print('resource open')
    print(a/b)
    
    
except Exception as e:
    print('error because',e)
    
    print('resource closed')
# Out:
# resource open
# error because division by zero
# resource closed

# %%
a=3
b=3

try:
    print('resource open')
    print(a/b)
    
    
except Exception as e:
    print('error because',e)
    print('resource closed')
# Out:
# resource open
# 1.0

# %%
a=3
b=3

try:
    print('resource open')
    print(a/b)
    
    
except Exception as e:
    print('error because',e)
    print('resource closed')
    
finally:
    print('resource closed')
# Out:
# resource open
# 1.0
# resource closed

# %%
a=3
b=0

try:
    print('resource open')
    print(a/b)
    
    
except Exception as e:
    print('error because',e)
    print('resource closed')
    
finally:
    print('resource closed')
# Out:
# resource open
# error because division by zero
# resource closed
# resource closed
